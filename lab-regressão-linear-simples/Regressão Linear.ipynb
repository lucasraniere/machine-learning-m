# %% [markdown]
# #### 1. Rode o mesmo programa nos dados contendo anos de escolaridade (primeira coluna) versus salário (segunda coluna). Baixe os dados no link: income.csv Visualizar o documento. Esse exemplo foi trabalhado em sala de aula.

# %%
from numpy import*

def compute_error_for_given_points(b, m, points):
    totalError = 0
    for i in range(0, len(points)):
        x = points[i, 0]
        y = points[i, 1]
        totalError += (y - (m * x + b)) **2
    return totalError/float(len(points))

def step_gradient(b_current, m_current, points, learningRate):
    #gradiente descedente
    b_gradient = 0
    m_gradient = 0
    N = float(len(points))
    for i in range(0, len(points)):
        x = points[i, 0]
        y = points[i, 1]
        b_gradient += -(2/N) * (y - ((m_current * x) + b_current))
        m_gradient += -(2/N) * x * (y - ((m_current * x) + b_current))
    new_b = b_current - (learningRate * b_gradient)
    new_m = m_current - (learningRate * m_gradient)
    return [new_b, new_m]

def gradient_descent_runner(points, starting_b, starting_m, learning_rate, num_iterations):
    b = starting_b
    m = starting_m

    for i in range(num_iterations):
        b, m = step_gradient(b, m, array(points), learning_rate)
    return [b, m]

def run():
    points = genfromtxt("income.csv", delimiter=",")
    learning_rate = 0.0001
    
    #y = mx +b
    initial_b = 0
    initial_m = 0
    num_iterations = 1000
    print("Descida de gradiente iniciando em b = {0}, m = {1}, erro = {2}".format(initial_b, initial_m, compute_error_for_given_points(initial_b, initial_m, points)))
    print("Rodando...")
    [b, m] = gradient_descent_runner(points, initial_b, initial_m, learning_rate, num_iterations)
    print("Após {0} interações b = {1}, m = {2}, erro = {3}".format(num_iterations, b, m, compute_error_for_given_points(b, m, points)))

# %%
if __name__ == '__main__':
    run()
# Out:
# Descida de gradiente iniciando em b = 0, m = 0, erro = 2946.6344970460195
# Rodando...
# Após 1000 interações b = -0.18234255376510086, m = 3.262182267596014, erro = 103.39842291729676

# %% [markdown]
# #### 2. Modifique o código original para imprimir o RSS a cada iteração do gradiente descendente.

# %%
from numpy import*

def compute_error_for_given_points(b, m, points):
    totalError = 0
    for i in range(0, len(points)):
        x = points[i, 0]
        y = points[i, 1]
        totalError += (y - (m * x + b)) **2
    return totalError/float(len(points))

def step_gradient(b_current, m_current, points, learningRate):
    #gradiente descedente
    b_gradient = 0
    m_gradient = 0
    N = float(len(points))
    for i in range(0, len(points)):
        x = points[i, 0]
        y = points[i, 1]
        b_gradient += -(2/N) * (y - ((m_current * x) + b_current))
        m_gradient += -(2/N) * x * (y - ((m_current * x) + b_current))
    new_b = b_current - (learningRate * b_gradient)
    new_m = m_current - (learningRate * m_gradient)
    return [new_b, new_m]

def gradient_descent_runner(points, starting_b, starting_m, learning_rate, num_iterations):
    b = starting_b
    m = starting_m

    for i in range(num_iterations):
        b, m = step_gradient(b, m, array(points), learning_rate)
        print("RSS na interação {0}: {1}".format(i, compute_error_for_given_points(b, m, points)))
    return [b, m]



def run():
    points = genfromtxt("income.csv", delimiter=",")
    learning_rate = 0.0001
    
    #y = mx +b
    initial_b = 0
    initial_m = 0
    num_iterations = 1000
    print("Descida de gradiente iniciando em b = {0}, m = {1}, erro = {2}".format(initial_b, initial_m, compute_error_for_given_points(initial_b, initial_m, points)))
    print("Rodando...")
    [b, m] = gradient_descent_runner(points, initial_b, initial_m, learning_rate, num_iterations)
    print("Após {0} interações b = {1}, m = {2}, erro = {3}".format(num_iterations, b, m, compute_error_for_given_points(b, m, points)))

# %%
if __name__ == '__main__':
    run()
# Out:
# Descida de gradiente iniciando em b = 0, m = 0, erro = 2946.6344970460195
# Rodando...
# RSS na interação 0: 2648.2381266261386
# RSS na interação 1: 2381.1735926230144
# RSS na interação 2: 2142.151013653971
# RSS na interação 3: 1928.2259499305476
# RSS na interação 4: 1736.7631314659504
# RSS na interação 5: 1565.4039948653665
# RSS na interação 6: 1412.0376287932477
# RSS na interação 7: 1274.7747702022896
# RSS na interação 8: 1151.924530990372
# RSS na interação 9: 1041.9735683871631
# RSS na interação 10: 943.5674424757678
# RSS na interação 11: 855.4939311975465
# RSS na interação 12: 776.6680973019634
# RSS na interação 13: 706.1189232850785
# RSS na interação 14: 642.9773496759485
# RSS na interação 15: 586.4655693176774
# RSS na interação 16: 535.8874457621318
# RSS na interação 17: 490.61993774500473
# RSS na interação 18: 450.105424101551
# RSS na interação 19: 413.8448345756185
# RSS na interação 20: 381.3915019021827
# RSS na interação 21: 352.34565942878487
# ...

# %% [markdown]
# #### 3. O que acontece com o RSS ao longo das iterações (aumenta ou diminui) se você usar 1000 iterações? Plote o RSS vs número de iterações.

# %% [markdown]
# O RSS diminui a cada interação. Iniciando em 2946.634 e terminando em 103.398

# %% [markdown]
# #### 4.Teste valores diferentes do número de iterações e learning_rate até que w0 e w1 sejam aproximadamente iguais a -39 e 5 respectivamente. Reporte os valores do número de iterações e learning_rate usados para atingir esses valores.

# %%
from numpy import*

def compute_error_for_given_points(b, m, points):
    totalError = 0
    for i in range(0, len(points)):
        x = points[i, 0]
        y = points[i, 1]
        totalError += (y - (m * x + b)) **2
    return totalError/float(len(points))



def step_gradient(b_current, m_current, points, learningRate):
    #gradiente descedente
    b_gradient = 0
    m_gradient = 0
    N = float(len(points))
    for i in range(0, len(points)):
        x = points[i, 0]
        y = points[i, 1]
        b_gradient += -(2/N) * (y - ((m_current * x) + b_current))
        m_gradient += -(2/N) * x * (y - ((m_current * x) + b_current))
    new_b = b_current - (learningRate * b_gradient)
    new_m = m_current - (learningRate * m_gradient)
    return [new_b, new_m]

def gradient_descent_runner(points, starting_b, starting_m, learning_rate, num_iterations):
    b = starting_b
    m = starting_m

    for i in range(num_iterations):
        b, m = step_gradient(b, m, array(points), learning_rate)
    return [b, m]



def run():
    points = genfromtxt("income.csv", delimiter=",")
    learning_rate = 0.002 ##
    
    #y = mx +b
    initial_b = 0
    initial_m = 0
    num_iterations = 25000 ##
    print("Descida de gradiente iniciando em b = {0}, m = {1}, erro = {2}".format(initial_b, initial_m, compute_error_for_given_points(initial_b, initial_m, points)))
    print("Rodando...")
    [b, m] = gradient_descent_runner(points, initial_b, initial_m, learning_rate, num_iterations)
    print("Após {0} interações b = {1}, m = {2}, erro = {3}".format(num_iterations, b, m, compute_error_for_given_points(b, m, points)))

# %%
if __name__ == '__main__':
    run()
# Out:
# Descida de gradiente iniciando em b = 0, m = 0, erro = 2946.6344970460195
# Rodando...
# Após 25000 interações b = -39.10526733185249, m = 5.579184474791039, erro = 29.834364919838457

# %% [markdown]
# #### 5. O algoritmo do vídeo usa o número de iterações como critério de parada. Mude o algoritmo para considerar um critério de parada que é relacionado ao tamanho do gradiente (como no algoritmo apresentado em sala). Plote o tamanho do gradiente vs número de iterações.

# %%
from numpy import*
import matplotlib.pyplot as plt

def compute_error_for_given_points(b, m, points):
    totalError = 0
    for i in range(0, len(points)):
        x = points[i, 0]
        y = points[i, 1]
        totalError += (y - (m * x + b)) **2
    return totalError/float(len(points))



def step_gradient(b_current, m_current, points, learningRate):
    #gradiente descedente
    b_gradient = 0
    m_gradient = 0
    N = float(len(points))
    for i in range(0, len(points)):
        x = points[i, 0]
        y = points[i, 1]
        b_gradient += -(2/N) * (y - ((m_current * x) + b_current))
        m_gradient += -(2/N) * x * (y - ((m_current * x) + b_current))
    new_b = b_current - (learningRate * b_gradient)
    new_m = m_current - (learningRate * m_gradient)
    return [new_b, new_m, b_gradient, m_gradient]

def plot_gradient(gradient_array):
    iterations_array = range(1, len(gradient_array)+1)
    plt.scatter(iterations_array, gradient_array, alpha=0.5, s=100, c="red",)
    plt.title('Valor do gradiente x numero de interações')
    plt.xlabel("Iterations")
    plt.ylabel("Gradient")
    plt.xscale('log')
    plt.show()

def gradient_descent_runner(points, starting_b, starting_m, learning_rate, num_iterations, tolerance):
    b = starting_b
    m = starting_m
    b_gradient = 0 
    m_gradient = 0    
    gradient = None
    gradient_array = []
    
    iterations = 0;
    while gradient == None or gradient >= tolerance:
        
        b, m, b_gradient, m_gradient = step_gradient(b, m, array(points), learning_rate)                   
        
        gradient = math.sqrt(b_gradient**2 + m_gradient**2)
        gradient_array.append(gradient)
        iterations += 1
        
    plot_gradient(gradient_array)
    
    return [b, m]
        

def run():
    points = genfromtxt("income.csv", delimiter=",")
    learning_rate = 0.003 ##
    
    #y = mx +b
    initial_b = 0
    initial_m = 0
    num_iterations = 1000 ##
    [b, m] = gradient_descent_runner(points, initial_b, initial_m, learning_rate, num_iterations, 0.04)
    
    print("Descida de gradiente iniciando em b = {0}, m = {1}, erro = {2}".format(initial_b, initial_m, compute_error_for_given_points(initial_b, initial_m, points)))
    print("Rodando...")
    print("Após {0} interações b = {1}, m = {2}, erro = {3}".format(num_iterations, b, m, compute_error_for_given_points(b, m, points)))

# %%
if __name__ == '__main__':
    run()
# Out:
# Descida de gradiente iniciando em b = 0, m = 0, erro = 2946.6344970460195
# Rodando...
# Após 1000 interações b = -39.026550442698195, m = 5.574498619168578, erro = 29.837222445042283

# %% [markdown]
# #### 6. Ache um valor de tolerância que se aproxime dos valores dos parâmetros do item 4 acima. Que valor foi esse?

# %% [markdown]
# Tolerância = 0,04
